# %% [markdown]
# ## Observations and Insights
#    1) Capomulin and Ramicane have the greatest affect on tumor shrinkage over time with over all of the other treatments.
#
#    2) Out of the four best treatments (Capomulin, Ramicane, Infubinol, and Ceftamin), Ceftamin has the greatest range in final tumor volume.
#
#    3) The study had a almost equal number of both male and female participants, which proved to be a good indicator of differences between the two with each treatment.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from scipy.stats import sem

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata, study_results, how="outer", on=["Mouse ID"])
# Display the data table for preview
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mice_total = len(combined_df["Mouse ID"].value_counts())
mice_total
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = combined_df.loc[combined_df.duplicated(subset=["Mouse ID", "Timepoint"]),"Mouse ID"].unique()
duplicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate = combined_df.set_index('Mouse ID')
duplicate.loc['g989']
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         25
# g989         Propriva  Female          21          26         30
# g989         Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_df.loc[combined_df['Mouse ID'] != "g989"]
clean_df.head(-1)
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1887     z969     Naftisol  Male           9          30         20
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
new_mouse_count = len(clean_df["Mouse ID"].value_counts())
new_mouse_count_df = new_mouse_count
new_mouse_count_df
# Out:
# 248

# %%
new_mouse_count_m = len(clean_df["Sex"].value_counts())
new_mouse_count_m_df = new_mouse_count_m
new_mouse_count_m_df
# Out:
# 2

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
regimen_df = clean_df.groupby("Drug Regimen")

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mean_tum = (regimen_df["Tumor Volume (mm3)"].mean())
median_tum = (regimen_df["Tumor Volume (mm3)"].median())
variance_tum = (regimen_df["Tumor Volume (mm3)"].var())
std_dev_tum = (regimen_df["Tumor Volume (mm3)"].std())
sem_tum = (regimen_df["Tumor Volume (mm3)"].sem())

# Assemble the resulting series into a single summary dataframe.
summary_df = pd.DataFrame({"Volume Mean": mean_tum,
                          "Volume Median": median_tum,
                          "Volume Variance": variance_tum,
                          "Volume Std Deviation": std_dev_tum,
                          "Volume SEM": sem_tum})
summary_df
# Out:
#               Volume Mean  Volume Median  Volume Variance  \
# Drug Regimen
# Capomulin       40.675741      41.557809        24.947764
# Ceftamin        52.591172      51.776157        39.290177
# Infubinol       52.884795      51.820584        43.128684
# Ketapril        55.235638      53.698743        68.553577
# Naftisol        54.331565      52.509285        66.173479
# Placebo         54.033581      52.288934        61.168083
# Propriva        52.320930      50.446266        43.852013
# Ramicane        40.216745      40.673236        23.486704
# Stelasyn        54.233149      52.431737        59.450562
# Zoniferol       53.236507      51.818479        48.533355
#
#               Volume Std Deviation  Volume SEM
# Drug Regimen
# Capomulin                 4.994774    0.329346
# Ceftamin                  6.268188    0.469821
# Infubinol                 6.567243    0.492236
# Ketapril                  8.279709    0.603860
# Naftisol                  8.134708    0.596466
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
regimen_df = clean_df.groupby("Drug Regimen")

# Using the aggregation method, produce the same summary statistics in a single line
regimen_df_agg = regimen_df.agg({'Tumor Volume (mm3)': (['mean', 'median', 'var', 'std', 'sem'])})
regimen_df_agg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
regimen_barplot_df = combined_df.groupby("Drug Regimen").count()["Timepoint"]
barplot_df = pd.DataFrame(regimen_barplot_df)

tp_plot = barplot_df.plot(kind="bar", figsize=(10,5))
plt.xlabel("Drug Regimen")
plt.ylabel("Total Timepoints")
plt.title("Timepoints per Drug Regimen")

plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
regimen_barplot_df = combined_df.groupby("Drug Regimen").count()["Timepoint"]
barplot_df = pd.DataFrame(regimen_barplot_df)

x_axis = np.arange(len(barplot_df))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(10,5))

newbarplot_df = barplot_df.reset_index()

plt.bar(x_axis, barplot_df['Timepoint'], color='g', align="center")
plt.xticks(tick_locations, newbarplot_df['Drug Regimen'], rotation="vertical")

plt.xlim(-0.75, len(regimen_barplot_df))
plt.ylim(0, max(barplot_df['Timepoint'])+10)
plt.xlabel("Drug Regimen")
plt.ylabel("Total Timepoints")
plt.title("Timepoints per Drug Regimen")
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex = combined_df.groupby(["Mouse ID", "Sex"])
sex_df = pd.DataFrame(sex.size())
mice_gen = pd.DataFrame(sex_df.groupby(["Sex"]).count())
mice_gen.columns = ["Counts"]

colors = ["pink", "steelblue"]
explode = (0.05, 0)
pie_pandas = mice_gen.plot.pie(y='Counts', explode=explode, startangle=90, colors=colors, shadow=True, autopct="%1.1f%%")
plt.title('Male Versus Female Mouse Distribution', fontsize=14)
plt.axis("equal")
plt.ylabel('Sex', fontsize=12)
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender = ["Male", "Female"]
counts = [125, 124]
colors = ["steelblue", "pink"]
explode = (0.1, 0)
plt.pie(counts, explode=explode, labels=gender, colors=colors, autopct = "%1.1f%%", startangle=90, shadow=True)
plt.title("Male Versus Female Mouse Distribution")
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
final_timepoint_df = clean_df.groupby(['Mouse ID'])
final_timepoint_df = final_timepoint_df['Timepoint'].max()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
final_merge = pd.merge(clean_df, final_timepoint_df, on=('Mouse ID', 'Timepoint'))
final_merge
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 243     z314     Stelasyn  Female          21          28          5
# 244     z435     Propriva  Female          12          26         10
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_volume_data = []
drug_1 = []
drug_2 = []
drug_3 = []
drug_4 = []

for drug in treatments:
    tumor_volume_data.append(final_merge.loc[final_merge['Drug Regimen'] == drug, :])
    
drug_1 = tumor_volume_data[0]['Tumor Volume (mm3)']
drug_2 = tumor_volume_data[1]['Tumor Volume (mm3)']
drug_3 = tumor_volume_data[2]['Tumor Volume (mm3)']
drug_4 = tumor_volume_data[3]['Tumor Volume (mm3)']

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatments:
    quartiles = final_merge.loc[final_merge['Drug Regimen'] == drug, :]['Tumor Volume (mm3)'].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    
    print(f"The lower quartile of {drug} is: {lowerq}")
    print(f"The upper quartile of {drug} is: {upperq}")
    print(f"The interquartile range of {drug} is : {iqr}")
    print(f"The median of {drug} is: {quartiles[0.5]}")
    
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Capomulin is: 32.37735684
# The upper quartile of Capomulin is: 40.1592203
# The interquartile range of Capomulin is : 7.781863460000004
# The median of Capomulin is: 38.1251644
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.
# The lower quartile of Ramicane is: 31.56046955
# The upper quartile of Ramicane is: 40.65900627
# The interquartile range of Ramicane is : 9.098536719999998
# The median of Ramicane is: 36.56165229
# Values below 17.912664470000003 could be outliers.
# Values above 54.30681135 could be outliers.
# The lower quartile of Infubinol is: 54.04860769
# The upper quartile of Infubinol is: 65.52574285
# The interquartile range of Infubinol is : 11.477135160000003
# The median of Infubinol is: 60.16518046
# Values below 36.83290494999999 could be outliers.
# Values above 82.74144559000001 could be outliers.
# The lower quartile of Ceftamin is: 48.72207785
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume per Drug Regimen')
ax1.set_ylabel('Tumor Volume (mm3)')

ax1.boxplot([drug_1, drug_2, drug_3, drug_4], flierprops={'markerfacecolor': 'g'})
plt.xticks([1,2,3,4], treatments)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouse_id = clean_df.set_index('Mouse ID')
m601 = mouse_id.loc['m601']
x_values = m601['Timepoint']
y_values = m601['Tumor Volume (mm3)']
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Mouse m601: Tumor Volume Versus Timepoint')
plt.plot(x_values, y_values)

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
weight = final_merge.loc[final_merge['Drug Regimen'] == 'Capomulin']
weight_avg = weight.groupby('Mouse ID').mean()
x_values = weight_avg['Weight (g)']
y_values = weight_avg['Tumor Volume (mm3)']
plt.title('Capomulin - Average Mouse Weight Versus Tumor Volume')
plt.xlabel('Average Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.scatter(x_values, y_values)
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
weight = final_merge.loc[final_merge['Drug Regimen'] == 'Capomulin']
weight_avg = weight.groupby('Mouse ID').mean()
x_values = weight_avg["Weight (g)"]
y_values = weight_avg["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')
plt.xlabel("Average Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Capomulin - Average Mouse Weight Versus Tumor Volume')
plt.show()
